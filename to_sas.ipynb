# %%
import pandas as pd

# %%
df = pd.read_csv('./output/7.csv')
print(len(df['ICD10編碼']))
df['ICD10編碼'].drop_duplicates(inplace = True)
print(len(df['ICD10編碼']))
# Out:
# 213
# 189

# %%
sas_list = []
# head = 2
# last = 116
# sas_list = df['ICD10編碼'][head-2:last-1]
df['ICD10編碼'].drop_duplicates(inplace = True)
sas_list = df['ICD10編碼']
s = 'where=('
s1 = '"'
for i in sas_list:
    i = i.replace('.', '')
    print(i)
    s += 'icd9cm_code like ' + s1 + str(i) + s1 + ' or '
s = s.rstrip(" or ")
s += ')'
s
# Out:
# M8000XA
# M8080XA
# M8440XA
# M8450XA
# M8460XA
# M80021A
# M80022A
# M80029A
# M80821A
# M80822A
# M80829A
# M84421A
# M84422A
# M84429A
# M84521A
# M84522A
# M84529A
# M84621A
# M84622A
# M84629A
# M80031A
# M80032A
# M80039A
# M80831A
# M80832A
# M80839A
# M84431A
# M84432A
# M84433A
# M84434A
# M84439A
# M84531A
# M84532A
# M84533A
# M84534A
# M84539A
# M84631A
# M84632A
# M84633A
# M84634A
# M84639A
# M4850XA
# M4851XA
# M4852XA
# M4853XA
# M4854XA
# M4855XA
# M4856XA
# M4857XA
# M4858XA
# M8008XA
# M8088XA
# M8448XA
# M8458XA
# M8468XA
# M80051A
# M80052A
# M80059A
# M80851A
# M80852A
# M80859A
# M84451A
# M84452A
# M84459A
# M84551A
# M84552A
# M84553A
# M84559A
# M84651A
# M84652A
# M84653A
# M84659A
# M84453A
# M80061A
# M80062A
# M80069A
# M80071A
# M80072A
# M80079A
# M80861A
# M80862A
# M80869A
# M80871A
# M80872A
# M80879A
# M84361A
# M84362A
# M84363A
# M84364A
# M84369A
# M84461A
# M84462A
# M84463A
# M84464A
# M84469A
# M84471A
# M84472A
# M84473A
# M84561A
# M84562A
# ...
